# %% [markdown]
# Paso 0 — Objetivo del EDA (lo que quieres responder)
#
# ¿Cuándo ocurre más fraude? (hora, día semana, tendencia mensual)
#
# ¿Dónde ocurre más fraude? (estado, ciudad/zip con filtro de volumen)
#
# ¿En qué tipo de comercio? (category, merchant)
#
# ¿En qué perfiles? (edad, género, job, ciudad_pop)
#
# ¿Influye el contexto económico? (income: avg_agi, income_level, amt_vs_avg_agi, taxable_share)
